# %%
import pandas as pd

# %%
df_stroke = pd.read_csv('../data/stroke_data_cleanedJB.csv')

# %%
df_stroke
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 0      30669    Male   3.0             0              0           No
# 1      30468    Male  58.0             1              0          Yes
# 2      16523  Female   8.0             0              0           No
# 3      56543  Female  70.0             0              0          Yes
# 4      46136    Male  14.0             0              0           No
# ...      ...     ...   ...           ...            ...          ...
# 43384  56196  Female  10.0             0              0           No
# 43385   5450  Female  56.0             0              0          Yes
# 43386  28375  Female  82.0             1              0          Yes
# 43387  27973    Male  40.0             0              0          Yes
# 43388  36271  Female  82.0             0              0          Yes
#
#       work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
for column in df_stroke.columns:
    if column not in ["id", "age", "avg_glucose_level", "bmi"]:
        print(df_stroke[column].value_counts())
        print((df_stroke[column].value_counts() / len(df_stroke))*100)
# Out:
# Female    25665
# Male      17724
# Name: gender, dtype: int64
# Female    59.150937
# Male      40.849063
# Name: gender, dtype: float64
# 0    39328
# 1     4061
# Name: hypertension, dtype: int64
# 0    90.640485
# 1     9.359515
# Name: hypertension, dtype: float64
# 0    41327
# 1     2062
# Name: heart_disease, dtype: int64
# 0    95.247643
# 1     4.752357
# Name: heart_disease, dtype: float64
# Yes    27933
# No     15456
# Name: ever_married, dtype: int64
# Yes    64.378068
# No     35.621932
# Name: ever_married, dtype: float64
# Private          24827
# Self-employed     6793
# children          6293
# Govt_job          5438
# Never_worked        38
# Name: work_type, dtype: int64
# Private          57.219572
# Self-employed    15.656042
# children         14.503676
# Govt_job         12.533131
# Never_worked      0.087580
# Name: work_type, dtype: float64
# Urban    21751
# Rural    21638
# Name: Residence_type, dtype: int64
# Urban    50.130217
# Rural    49.869783
# ...

# %%
print(sum(pd.isna(df_stroke["smoking_status"])))
print((sum(pd.isna(df_stroke["smoking_status"])) / len(df_stroke))*100)
# Out:
# 7791
# 17.95616400470165

# %%
for column in ["age", "avg_glucose_level", "bmi"]:
    print(column)
    print(df_stroke[column].mean())
    print(df_stroke[column].std())
# Out:
# age
# 42.21974694046879
# 22.52074979786506
# avg_glucose_level
# 104.48675977782386
# 43.11515686001645
# bmi
# 28.605156089766524
# 7.770185740109893
